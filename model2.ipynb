# %%
import math
import numpy as np

LENGTH=20
WIDTH=1920
HEIGHT=1080
FRAMERATE=30
color_purple = (255,0,255)
color_white = (255,255,255)

# %%
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon

import cv2
import numpy as np

class TrackedVehicle:
    def __init__(self, label, speed,time):
        self.label = label
        self.speed = speed
        self.time = time

class TrackableVehicle:
    def __init__(self, id: int,
                  entered_timestamp: float | None,
                  last_anchor, label, indim) -> None:
        self.id = id
        self.enter_timestamp = entered_timestamp
        self.last_anchor = list()
        self.last_anchor.append((int(last_anchor[0]),int(last_anchor[1])))
        self.labels = dict()
        self.labels[label] = 1
        self.indims = indim


    def label(self):
        return max(self.labels, key=self.labels.get)


    def finish(self, time):
        return TrackedVehicle(self.label(),LENGTH/(time-self.enter_timestamp),time-self.enter_timestamp if self.enter_timestamp is not None else 0)
    
    def update(self, label, anchor, isins):
        if label not in self.labels.keys():
            self.labels[label] = 1
        else:
            self.labels[label] +=1
        self.last_anchor.append((int(x), int(y+h/2)))  # x, y center point
        if len(self.last_anchor) > 10:
            self.last_anchor.pop(0)
        self.indim=isins

    def old_anchor(self):
        return self.last_anchor[0]

def avspeed(tracked):
    n = 0
    sp = 0
    for v in tracked:
        if v.time>=0.5: 
            sp+=v.speed
            n+=1
    if n==0: return "NaN"
    return (sp/n)*3.6

def check_in(x, y, poly):
    return Polygon(poly).contains(Point(x,y))

def in_any(x, y, polys):
    for poly in polys:
        if Polygon(poly).contains(Point(x,y)): return True
    return False

# %%
from collections import defaultdict

from ultralytics import YOLO

import json


video_path=r"videos/dataset/Test_Newest_2/000.mp4"
markup=r"videos/dataset/Test_markup/000.json"

with open(markup, 'r') as file:
    data = json.load(file)

zones = data['zones']



# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# Open the video file
cap = cv2.VideoCapture(video_path)

WIDTH=cap.get(cv2.CAP_PROP_FRAME_WIDTH)
HEIGHT=cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
FRAMERATE=cap.get(cv2.CAP_PROP_FPS)

dims = []
for i, arr in enumerate(zones):
    dims.append([])
    for j, arr2 in enumerate(arr):
        dims[i].append((int(WIDTH*arr2[0]),int(HEIGHT*arr2[1])))

areas = data['areas']

bdims = []
for i, arr in enumerate(areas):
    bdims.append([])
    for j, arr2 in enumerate(arr):
        bdims[i].append((int(WIDTH*arr2[0]),int(HEIGHT*arr2[1])))

# Store the track history
track_history = defaultdict(lambda: [])

needed_classes=[1,2,3,5,7]

all_ids=dict()
tracking=dict()
tracked=dict()

old_ids = []

font = cv2.FONT_HERSHEY_DUPLEX
color = (255,255,255)
fontsize = 1

count=0
# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()
    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True, tracker='bytetrack.yaml', classes=needed_classes)

        # Get the boxes and track IDs
        tracks = results[0].boxes.cpu()
        boxes = results[0].boxes.xywh.cpu()
        track_ids = results[0].boxes.id.int().cpu().tolist()

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Plot the tracks
        for box, track_id in zip(boxes, track_ids):
            x, y, w, h = box
            track = track_history[track_id]
            track.append((float(x), float(y+h/2)))  # x, y center point
            if len(track) > 90:  # retain 90 tracks for 90 frames
                track.pop(0)

            # Draw the tracking lines
            points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
            cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=10)

        # Plot markup
        for i in range(len(dims)):
            cv2.line(annotated_frame, tuple(dims[i][0]), tuple(dims[i][1]), color_purple, thickness=4, lineType=8, shift=0)
            cv2.line(annotated_frame, tuple(dims[i][1]), tuple(dims[i][2]), color_purple, thickness=4, lineType=8, shift=0)
            cv2.line(annotated_frame, tuple(dims[i][2]), tuple(dims[i][3]), color_purple, thickness=4, lineType=8, shift=0)
            cv2.line(annotated_frame, tuple(dims[i][3]), tuple(dims[i][0]), color_purple, thickness=4, lineType=8, shift=0)

        for i in range(len(bdims)):
            cv2.line(annotated_frame, tuple(bdims[i][0]), tuple(bdims[i][1]), color_purple, thickness=4, lineType=8, shift=0)
            cv2.line(annotated_frame, tuple(bdims[i][1]), tuple(bdims[i][2]), color_purple, thickness=4, lineType=8, shift=0)
            cv2.line(annotated_frame, tuple(bdims[i][2]), tuple(bdims[i][3]), color_purple, thickness=4, lineType=8, shift=0)
            cv2.line(annotated_frame, tuple(bdims[i][3]), tuple(bdims[i][0]), color_purple, thickness=4, lineType=8, shift=0)
        
        
        for box, id, track in zip(boxes, track_ids, tracks):
            x,y,w,h = box
            isin = in_any(float(x), float(y+h/2), bdims)
            isins = in_any(float(x), float(y+h/2), dims)
            if isin: 
                cv2.circle(annotated_frame, tuple((int(x), int(y+h/2))), 10, (255,0,0), 10)
            if ((id not in tracking.keys()) and isin and isins) or (id in tracking.keys() and (not isin)):


                if id not in tracking.keys(): tracking[id] = TrackableVehicle(id,None,(int(x), int(y+h/2)),track.cls,isins)
                
                if isin and isins:
                    tracking[id].enter_timestamp = (1/FRAMERATE)*count

                elif (not isin) and tracking[id].indims != isins:
                    if (1/FRAMERATE)*count!=tracking[id].enter_timestamp:
                        tracked[tracking[id].label()] = tracking[id].finish((1/FRAMERATE)*count)
                        tracking.pop(id)
                
            if id in tracking.keys(): tracking[id].update(track.cls, (int(x), int(y+h/2)), isins)
        cv2.putText(annotated_frame,  f"tracking inside: {len(tracking)}", (100,100), font, fontsize, color=color)
        cv2.putText(annotated_frame, f"tracking inside: {len(tracking)}", (100,100), font, fontsize, color=color)
        cv2.putText(annotated_frame, f"tracking everywhere: {len(track_ids)}", (100,140), font, fontsize, color=color)
        cv2.putText(annotated_frame, f"tracked and counted: {len(tracked)}", (100,180), font, fontsize, color=color)
        cv2.putText(annotated_frame, f"average speed: {avspeed(tracked.values())} km/h", (100,220), font, fontsize, color=color)

        # Display the annotated frame
        cv2.imshow("MIET hack team", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

    count+=1

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 2 cars, 38.8ms
# Speed: 10.3ms preprocess, 38.8ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 22.8ms
# Speed: 5.0ms preprocess, 22.8ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
#
# QObject::moveToThread: Current thread (0x1465fa20) is not the object's thread (0x27ce6850).
# Cannot move to target thread (0x1465fa20)
# 0: 384x640 2 cars, 43.6ms
# Speed: 7.1ms preprocess, 43.6ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 26.6ms
# Speed: 5.8ms preprocess, 26.6ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 20.5ms
# Speed: 2.8ms preprocess, 20.5ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 35.5ms
# Speed: 6.1ms preprocess, 35.5ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 36.6ms
# Speed: 3.0ms preprocess, 36.6ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 36.7ms
# Speed: 25.9ms preprocess, 36.7ms inference, 22.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 29.1ms
# Speed: 5.7ms preprocess, 29.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 36.8ms
# Speed: 6.2ms preprocess, 36.8ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 32.4ms
# Speed: 5.0ms preprocess, 32.4ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 18.0ms
# Speed: 3.1ms preprocess, 18.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 30.6ms
# Speed: 6.3ms preprocess, 30.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 47.0ms
# Speed: 6.0ms preprocess, 47.0ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 29.8ms
# Speed: 4.0ms preprocess, 29.8ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 26.0ms
# Speed: 8.8ms preprocess, 26.0ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 28.4ms
# Speed: 4.1ms preprocess, 28.4ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 43.3ms
# Speed: 6.9ms preprocess, 43.3ms inference, 12.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 28.6ms
# Speed: 4.0ms preprocess, 28.6ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 25.7ms
# Speed: 4.8ms preprocess, 25.7ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 22.3ms
# Speed: 3.9ms preprocess, 22.3ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 28.6ms
# Speed: 13.7ms preprocess, 28.6ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars,
4ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 34.2ms
# Speed: 4.2ms preprocess, 34.2ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 20.6ms
# Speed: 5.4ms preprocess, 20.6ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 26.6ms
# Speed: 5.7ms preprocess, 26.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 20.8ms
# Speed: 7.8ms preprocess, 20.8ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 24.3ms
# Speed: 7.0ms preprocess, 24.3ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 36.0ms
# Speed: 6.5ms preprocess, 36.0ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 22.7ms
# Speed: 8.3ms preprocess, 22.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 27.6ms
# Speed: 10.9ms preprocess, 27.6ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 19.3ms
# Speed: 3.3ms preprocess, 19.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.8ms
# Speed: 4.0ms preprocess, 18.8ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.2ms
# ...
#
# 0: 384x640 3 cars, 16.7ms
# Speed: 2.5ms preprocess, 16.7ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 25.7ms
# Speed: 3.5ms preprocess, 25.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 20.1ms
# Speed: 5.1ms preprocess, 20.1ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.8ms
# Speed: 2.8ms preprocess, 13.8ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.0ms
# Speed: 2.8ms preprocess, 16.0ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.9ms
# Speed: 2.6ms preprocess, 15.9ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 20.4ms
# Speed: 3.7ms preprocess, 20.4ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 10.3ms
# Speed: 2.3ms preprocess, 10.3ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.3ms
# Speed: 2.8ms preprocess, 13.3ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.0ms
# Speed: 2.8ms preprocess, 11.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.6ms
# Speed: 2.6ms preprocess, 15.6ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.5ms
# Speed: 3.8ms preprocess, 19.5ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 34.9ms
# Speed: 2.8ms preprocess, 34.9ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 9.9ms
# Speed: 3.1ms preprocess, 9.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 13.2ms
# Speed: 3.4ms preprocess, 13.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 11.2ms
# Speed: 2.1ms preprocess, 11.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 13.3ms
# Speed: 2.7ms preprocess, 13.3ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.2ms
# Speed: 4.4ms preprocess, 15.2ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.5ms
# Speed: 3.0ms preprocess, 16.5ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.9ms
# Speed: 2.4ms preprocess, 15.9ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 12.2ms
# Speed: 2.8ms preprocess, 12.2ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 9.4ms
# Speed: 3.0ms preprocess, 9.4ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 11.3ms
# Speed: 2.5ms preprocess, 11.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 9.8ms
# Speed: 2.4ms preprocess, 9.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 34.4ms
# Speed: 5.4ms preprocess, 34.4ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.5ms
# Speed: 3.8ms preprocess, 15.5ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 32.1ms
# Speed: 2.6ms preprocess, 32.1ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.6ms
# Speed: 2.4ms preprocess, 14.6ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.5ms
# Speed: 3.2ms preprocess, 14.5ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 11.4ms
# Speed: 2.7ms preprocess, 11.4ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 12.1ms
# Speed: 2.5ms preprocess, 12.1ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 13.1ms
# Speed: 3.4ms preprocess, 13.1ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.9ms
# Speed: 2.9ms preprocess, 15.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.5ms
# Speed: 3.4ms preprocess, 15.5ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 20.5ms
# Speed: 2.2ms preprocess, 20.5ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 11.1ms
# Speed: 2.3ms preprocess, 11.1ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 11.9ms
# Speed: 2.1ms preprocess, 11.9ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 13.9ms
# Speed: 2.4ms preprocess, 13.9ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.8ms
# Speed: 4.5ms preprocess, 14.8ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 9.4ms
# Speed: 3.0ms preprocess, 9.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 9.6ms
# Speed: 3.8ms preprocess, 9.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 27.0ms
# Speed: 6.7ms preprocess, 27.0ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 9.9ms
# Speed: 2.4ms preprocess, 9.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 8.5ms
# Speed: 2.4ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.3ms
# Speed: 2.7ms preprocess, 14.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.9ms
# Speed: 2.8ms preprocess, 16.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.8ms
# Speed: 3.3ms preprocess, 14.8ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.5ms
# Speed: 7.7ms preprocess, 17.5ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 9.9ms
# Speed: 2.3ms preprocess, 9.9ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.7ms
# Speed: 3.0ms preprocess, 14.7ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.0ms
# Speed: 2.2ms preprocess, 15.0ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 27.3ms
# Speed: 8.0ms preprocess, 27.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 10.0ms
# Speed: 2.5ms preprocess, 10.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 9.7ms
# Speed: 3.0ms preprocess, 9.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 9.2ms
# Speed: 2.7ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 12.6ms
# Speed: 2.1ms preprocess, 12.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.1ms
# Speed: 2.8ms preprocess, 15.1ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.7ms
# Speed: 5.4ms preprocess, 15.7ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 16.2ms
# Speed: 3.3ms preprocess, 16.2ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.3ms
# Speed: 3.1ms preprocess, 15.3ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 12.5ms
# Speed: 2.4ms preprocess, 12.5ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.8ms
# Speed: 2.5ms preprocess, 16.8ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 13.8ms
# Speed: 3.9ms preprocess, 13.8ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.4ms
# Speed: 2.3ms preprocess, 14.4ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 11.6ms
# Speed: 2.8ms preprocess, 11.6ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 9.6ms
# Speed: 2.2ms preprocess, 9.6ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 11.7ms
# Speed: 2.6ms preprocess, 11.7ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 13.7ms
# Speed: 2.5ms preprocess, 13.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.7ms
# Speed: 2.5ms preprocess, 17.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.2ms
# Speed: 8.6ms preprocess, 17.2ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.9ms
# Speed: 2.5ms preprocess, 15.9ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 32.1ms
# Speed: 4.4ms preprocess, 32.1ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 10.5ms
# Speed: 3.3ms preprocess, 10.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 8.8ms
# Speed: 4.1ms preprocess, 8.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 10.7ms
# Speed: 3.5ms preprocess, 10.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 9.2ms
# Speed: 2.5ms preprocess, 9.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.9ms
# Speed: 4.2ms preprocess, 14.9ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.9ms
# Speed: 3.1ms preprocess, 16.9ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.3ms
# Speed: 2.8ms preprocess, 14.3ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.7ms
# Speed: 2.2ms preprocess, 13.7ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.1ms
# Speed: 2.8ms preprocess, 14.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 9.4ms
# Speed: 2.3ms preprocess, 9.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.7ms
# Speed: 3.6ms preprocess, 15.7ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 31.9ms
# Speed: 4.5ms preprocess, 31.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 9.0ms
# Speed: 2.7ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 38.7ms
# Speed: 2.8ms preprocess, 38.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 13.8ms
# Speed: 2.0ms preprocess, 13.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 13.6ms
# Speed: 3.1ms preprocess, 13.6ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 12.0ms
# Speed: 2.5ms preprocess, 12.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 10.3ms
# Speed: 2.4ms preprocess, 10.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 13.8ms
# Speed: 4.5ms preprocess, 13.8ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 42.6ms
# Speed: 3.6ms preprocess, 42.6ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 18.3ms
# Speed: 2.7ms preprocess, 18.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 20.8ms
# Speed: 4.7ms preprocess, 20.8ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.4ms
# Speed: 2.7ms preprocess, 15.4ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.5ms
# Speed: 3.1ms preprocess, 15.5ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 11.8ms
# Speed: 2.7ms preprocess, 11.8ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.6ms
# Speed: 4.2ms preprocess, 16.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.4ms
# Speed: 2.7ms preprocess, 49.4ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 13.5ms
# Speed: 2.5ms preprocess, 13.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.4ms
# Speed: 3.9ms preprocess, 16.4ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 20.7ms
# Speed: 3.7ms preprocess, 20.7ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.0ms
# Speed: 5.1ms preprocess, 14.0ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.2ms
# Speed: 2.6ms preprocess, 15.2ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.3ms
# Speed: 3.7ms preprocess, 14.3ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.4ms
# Speed: 2.9ms preprocess, 15.4ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 22.4ms
# Speed: 2.9ms preprocess, 22.4ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.7ms
# Speed: 2.9ms preprocess, 16.7ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 26.3ms
# Speed: 3.7ms preprocess, 26.3ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.5ms
# Speed: 3.0ms preprocess, 17.5ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.1ms
# Speed: 3.4ms preprocess, 24.1ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 29.3ms
# Speed: 3.3ms preprocess, 29.3ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 13.5ms
# Speed: 2.9ms preprocess, 13.5ms inference, 69.2ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/ramil/workspace/aihacks_int/model2.ipynb Cell 4 line 6
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/ramil/workspace/aihacks_int/model2.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=66'>67</a> tracks = results[0].boxes.cpu()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/ramil/workspace/aihacks_int/model2.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=67'>68</a> boxes = results[0].boxes.xywh.cpu()
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/ramil/workspace/aihacks_int/model2.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=68'>69</a> track_ids = results[0].boxes.id.int().cpu().tolist()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/ramil/workspace/aihacks_int/model2.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=70'>71</a> # Visualize the results on the frame
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/ramil/workspace/aihacks_int/model2.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=71'>72</a> annotated_frame = results[0].plot()
#
# AttributeError: 'NoneType' object has no attribute 'int'

# %%
model.model.names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/ramil/workspace/aihacks_int/model2.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/ramil/workspace/aihacks_int/model2.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> model.model.names
#
# NameError: name 'model' is not defined
